# %%
# 수만장을 불러들일려면 폴더에서 하나씩 가져오는 방법을 알아야 한다.

# %%
from PIL import Image

# %%
import numpy as np

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
os.listdir('/Users/jung-kyoyoon/python_source_code/img')
# Out:
# ['2.jpg', '1.jpg']

# %%
path = '/Users/jung-kyoyoon/python_source_code/img'

# %%
temp = []

# %%
for i in os.listdir(path):
    s = Image.open(os.path.join(path,i))
    t = np.array(s)
    temp.append(t)

# %%
temp
# Out:
# [array([[[184, 187, 192],
#          [184, 187, 192],
#          [184, 187, 192],
#          ...,
#          [188, 193, 197],
#          [187, 192, 196],
#          [187, 192, 196]],
#
#         [[184, 187, 192],
#          [184, 187, 192],
#          [184, 187, 192],
#          ...,
#          [189, 194, 198],
#          [189, 194, 198],
#          [189, 194, 198]],
#
#         [[184, 187, 192],
#          [184, 187, 192],
#          [184, 187, 192],
#          ...,
#          [189, 194, 198],
#          [190, 195, 199],
#          [190, 195, 199]],
#
#         ...,
#
#         [[185, 188, 193],
#          [185, 188, 193],
#          [185, 188, 193],
#          ...,
#          [170, 171, 175],
#          [172, 173, 177],
#          [174, 175, 179]],
#
#         [[186, 189, 194],
#          [186, 189, 194],
#          [186, 189, 194],
#          ...,
#          [169, 170, 174],
#          [171, 172, 176],
#          [173, 174, 178]],
#
#         [[186, 189, 194],
# ...

# %%
im = Image.open('/Users/jung-kyoyoon/python_source_code/img/1.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x11D3BFE80>

# %%
plt.rcParams['font.family'] = 'KoPubWorldDotum_Pro' # 한글폰트 등록하기 
plt.imshow(im)
plt.title('레이튼 미스터')
# ticks 제거 
plt.xticks([]) # 열 제거 
plt.yticks([]) # 행 제거 
plt.xlabel('예뻐요')
plt.ylabel('예뻐요')
# Out:
# Text(0, 0.5, '예뻐요')
