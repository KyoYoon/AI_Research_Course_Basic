# %%
# OpenCV

# %%
# !pip install opencv-python

# %%
# OpenCV로 읽어들이면 BGR 이므로 이를 RGB로 변환해야 함

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
im2 = cv2.imread('/Users/jung-kyoyoon/python_source_code/img/1.jpg') # numpy 로 만들었음

# %%
# cv2.imshow('image',im2) # plt.imshow와 다름

# %%
# cv2.waitKey(0)

# %%
# cv2.cvtColor

# %%
cv2.COLOR_BGR2RGB
# Out:
# 4

# %%
im3 = cv2.cvtColor(im2, 4)

# %%
plt.imshow(im3)

# %%
np_rgb = np.zeros_like(im2)
np_rgb[:,:,0] = im2[:,:,2]
np_rgb[:,:,1] = im2[:,:,1]
np_rgb[:,:,2] = im2[:,:,0]

# %%
plt.imshow(np_rgb)

# %%
plt.imshow(im3[200:,200:,:]) # slicing -> crop

# %%
img_rgb_numpy = im2[:,:,::-1] # -1 로 역순으로 바꾼다. BGR -> RGB (openCV로 읽어들이면 BGR이므로 역순으로 바꿔서 보여준다)

# %%
plt.imshow(img_rgb_numpy)
