# %%
import pandas as pd
import collections # namedtuple이 collections 패키지안에 존재

# %%
df = pd.read_excel("https://github.com/chris1610/pbpython/blob/master/data/sample-salesv3.xlsx?raw=True")

# %%
#df["date"] = pd.to_datetime(df['date']) # 데이터가 한 개 있으면 Timestamp, 두 개 이상이면 index

# %%
df
# Out:
#       account number                             name       sku  quantity  \
# 0             740150                       Barton LLC  B1-20000        39
# 1             714466                  Trantow-Barrows  S2-77896        -1
# 2             218895                        Kulas Inc  B1-69924        23
# 3             307599      Kassulke, Ondricka and Metz  S1-65481        41
# 4             412290                    Jerde-Hilpert  S2-34077         6
# 5             714466                  Trantow-Barrows  S2-77896        17
# 6             218895                        Kulas Inc  B1-65551         2
# 7             729833                        Koepp Ltd  S1-30248         8
# 8             714466                  Trantow-Barrows  S1-50961        22
# 9             737550     Fritsch, Russel and Anderson  S2-82423        14
# 10            146832                     Kiehn-Spinka  S2-82423        15
# 11            688981                      Keeling LLC  S2-00301         7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
# account number    1500 non-null int64
# name              1500 non-null object
# sku               1500 non-null object
# quantity          1500 non-null int64
# unit price        1500 non-null float64
# ext price         1500 non-null float64
# date              1500 non-null object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 82.1+ KB

# %%
# account number -> category data , date 를 datetime을 변환 pd.to_, sku 값 이상?

# %%
df["account number"] = df["account number"].astype('category')

# %%
df["date"] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
# account number    1500 non-null category
# name              1500 non-null object
# sku               1500 non-null object
# quantity          1500 non-null int64
# unit price        1500 non-null float64
# ext price         1500 non-null float64
# date              1500 non-null datetime64[ns]
# dtypes: category(1), datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 72.6+ KB

# %%
df.set_index('date').groupby('name')["ext price"].resample("M").sum().head(20) # 시계열 분석의 set_index 방식
# Out:
# name                             date
# Barton LLC                       2014-01-31     6177.57
#                                  2014-02-28    12218.03
#                                  2014-03-31     3513.53
#                                  2014-04-30    11474.20
#                                  2014-05-31    10220.17
#                                  2014-06-30    10463.73
#                                  2014-07-31     6750.48
#                                  2014-08-31    17541.46
#                                  2014-09-30    14053.61
#                                  2014-10-31     9351.68
#                                  2014-11-30     4901.14
#                                  2014-12-31     2772.90
# Cronin, Oberbrunner and Spencer  2014-01-31     1141.75
#                                  2014-02-28    13976.26
#                                  2014-03-31    11691.62
#                                  2014-04-30     3685.44
# ...

# %%
# 시계열 분석
# 1. 그래프 -> plot
# 2. 구간별로 묶기 -> resample

# %%
# object끼리 묶는 게 groupby 이다. 
# category끼리 묶는 게 crosstab 이다.
# 구간별로 묶는 게 resample 이다.
