# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.subplot(211) 열에 2개 행에 1개 그리고 첫번째

# %%
plt.style.use('classic')
plt.subplot(121)
plt.plot([1,2,3])
plt.subplot(122)
plt.plot([3,2,1])

# %%
fig,ax = plt.subplots(2,1)
ax[0].plot([1,2,3])

# %%
fig,ax = plt.subplots(figsize=(10,2)) # plt.subplots(1,1)과 동일 / 여러 개 그릴 수도 있으니까 보통 이렇게 시작한다. 
#fig.figsize=(10,3)
ax.plot([1,2,3])

# %%
fig,ax = plt.subplots(2,2,figsize=(10,2)) # plt.subplots(1,1)과 동일 / 여러 개 그릴 수도 있으니까 보통 이렇게 시작한다. 
#fig.figsize=(10,3)
ax[0,0].plot([1,2,3])
ax[0,1].plot([1,2,3]) # ax[0][1].plot([1,2,3])
ax[1,0].plot([1,2,3])
ax[1,1].plot([1,2,3])
