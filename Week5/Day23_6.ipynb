# %%
from skimage import data

# %%
import matplotlib.pyplot as plt

# %%
cat = data.chelsea()

# %%
plt.imshow(cat)

# %%
plt.imshow(cat[::-1,:,:])

# %%
a = [1,2,3,4,5,]

# %%
b = a[::-1]

# %%
b
# Out:
# [5, 4, 3, 2, 1]

# %%
import pandas as pd

# %%
# .values -> numpy 포맷
