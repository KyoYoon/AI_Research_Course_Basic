# %% [markdown]
# ### Using slightly altered colors to make a distinction between related data

# %%
import pandas as pd
import numpy as np
from plotnine import *
from plotnine.data import mtcars

# %matplotlib inline

# %%
n = 10
df = pd.DataFrame({'x': np.arange(n),
                   'y': np.arange(n),
                   'yfit': np.arange(n) + np.tile([-.2, .2], n//2),
                   'cat': ['a', 'b']*(n//2)})

# %%
(ggplot(df)
 + geom_col(aes('x', 'y', fill='cat'))
 + geom_point(aes('x', y='yfit', color='cat'))
 + geom_path(aes('x', y='yfit', color='cat'))
)
# Out:
# <ggplot: (-9223372029310183999)>

# %%
(ggplot(df)
 + geom_col(aes('x', 'y', fill='cat'))
 + geom_point(aes('x', y='yfit', color='cat'))
 + geom_path(aes('x', y='yfit', color='cat'))
 + scale_color_discrete(l=.4)                                     # new
)
# Out:
# <ggplot: (7543833499)>

# %%
(ggplot(df)
 + geom_col(aes('x', 'y', fill='cat'))
 + geom_point(aes('x', y='yfit', color='cat'))
 + geom_path(aes('x', y='yfit', color='cat'))
 + scale_color_discrete(l=.4)
 + guides(                                                        # new
     fill=guide_legend(title='Data'),
     color=guide_legend(title='Model'))
)
# Out:
# <ggplot: (-9223372029310205061)>

# %%
(ggplot(df, aes('x', 'y'))
 + geom_point())
# Out:
# <ggplot: (7544458276)>

# %%
(ggplot(df, aes('x', 'y', color='cat'))
 + geom_point())
# Out:
# <ggplot: (-9223372029310946798)>

# %%
(ggplot(df, aes('x', 'y', color='cat'))
 + geom_point()
 + stat_smooth(geom='smooth',position='identity',method='lm'))

#stat_smooth(mapping=None, data=None, geom='smooth', position='identity',
#                na_rm=False, level=0.95, fullrange=False, span=0.75, se=True,
#                method='auto', n=80, method_args={}, **kwargs)
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (7544457494)>

# %%
(ggplot(df, aes('x', 'y', color='cat'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~cat'))
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (273345558)>

# %%
(ggplot(df, aes('x', 'y', color='cat'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~cat')
 + theme_xkcd())
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223372029310472455)>

# %%
(ggplot(mtcars, aes('wt', 'mpg'))
 + geom_point())
# Out:
# <ggplot: (-9223372029309465221)>

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point())
# Out:
# <ggplot: (-9223372029310180222)>

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm'))
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (7544562941)>

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~gear'))
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223372029311830833)>

# %%
(ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~gear')
 + theme_xkcd())
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <ggplot: (-9223372029310335607)>
