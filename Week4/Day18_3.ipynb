# %%
import pandas as pd

# %%
tb = pd.read_csv('tb.csv')

# %%
tb
# Out:
#      iso2  year   new_sp  new_sp_m04  new_sp_m514  new_sp_m014  new_sp_m1524  \
# 0      AD  1989      NaN         NaN          NaN          NaN           NaN
# 1      AD  1990      NaN         NaN          NaN          NaN           NaN
# 2      AD  1991      NaN         NaN          NaN          NaN           NaN
# 3      AD  1992      NaN         NaN          NaN          NaN           NaN
# 4      AD  1993     15.0         NaN          NaN          NaN           NaN
# 5      AD  1994     24.0         NaN          NaN          NaN           NaN
# 6      AD  1996      8.0         NaN          NaN          0.0           0.0
# 7      AD  1997     17.0         NaN          NaN          0.0           0.0
# 8      AD  1998      1.0         NaN          NaN          0.0           0.0
# 9      AD  1999      4.0         NaN          NaN          0.0           0.0
# 10     AD  2000      1.0         NaN          NaN          0.0           0.0
# ...

# %%
s = tb.melt(id_vars=['iso2','year'])

# %%
s.dropna() # NaN 제거
# Out:
#        iso2  year   variable   value
# 4        AD  1993     new_sp    15.0
# 5        AD  1994     new_sp    24.0
# 6        AD  1996     new_sp     8.0
# 7        AD  1997     new_sp    17.0
# 8        AD  1998     new_sp     1.0
# 9        AD  1999     new_sp     4.0
# 10       AD  2000     new_sp     1.0
# 11       AD  2001     new_sp     3.0
# 12       AD  2002     new_sp     2.0
# 13       AD  2003     new_sp     7.0
# 14       AD  2004     new_sp     3.0
# 15       AD  2005     new_sp     5.0
# 16       AD  2006     new_sp     8.0
# 17       AD  2007     new_sp     2.0
# 18       AD  2008     new_sp     3.0
# 35       AE  1999     new_sp    31.0
# 36       AE  2000     new_sp    73.0
# 37       AE  2001     new_sp    69.0
# 38       AE  2002     new_sp    57.0
# 39       AE  2003     new_sp    77.0
# 40       AE  2004     new_sp    57.0
# 41       AE  2005     new_sp    62.0
# 42       AE  2006     new_sp    52.0
# 43       AE  2007     new_sp    56.0
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121149 entries, 0 to 121148
# Data columns (total 4 columns):
# iso2        120666 non-null object
# year        121149 non-null int64
# variable    121149 non-null object
# value       38831 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.7+ MB

# %%
s.describe()
# Out:
#                 year          value
# count  121149.000000   38831.000000
# mean     1994.229329    1282.241482
# std         8.422569   11550.117273
# min      1980.000000       0.000000
# 25%      1987.000000       5.000000
# 50%      1994.000000      45.000000
# 75%      2002.000000     318.000000
# max      2008.000000  615977.000000

# %%
# 위 상태에서 Group By 를 사용할 수 있다.

# %%
s.dropna().groupby('variable').mean()
# Out:
#                      year        value
# variable
# new_sp        2000.507336  9112.137268
# new_sp_f014   2001.680626   106.720389
# new_sp_f04    2006.847328     6.417303
# new_sp_f1524  2001.716807   761.138655
# new_sp_f2534  2001.712490   857.329841
# new_sp_f3544  2001.712668   587.705117
# new_sp_f4554  2001.726016   401.766234
# new_sp_f514   2006.849010    39.185644
# new_sp_f5564  2001.709664   277.324370
# new_sp_f65    2001.721243   256.435768
# new_sp_fu     2007.022140     2.549815
# new_sp_m014   2001.653570    79.711449
# new_sp_m04    2006.852041     8.806122
# new_sp_m1524  2001.697869   926.066026
# new_sp_m2534  2001.700919  1304.247285
# new_sp_m3544  2001.708455  1208.728446
# new_sp_m4554  2001.714167   987.455754
# new_sp_m514   2006.850374    28.975062
# new_sp_m5564  2001.706250   699.392083
# new_sp_m65    2001.700084   612.390142
# new_sp_mu     2007.025735     5.731618

# %%
# tidy data -> 분석하기 좋은 데이터
