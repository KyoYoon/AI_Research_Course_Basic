# %%
import numpy as np

# %%
import pandas as pd

# %%
# numpy 는 c 로 만들어져있다. 그래서 문자열 처리가 좋지 않아 바꾼다. 노래제목에 프랑스어가 끼어있는데 이걸 C 언어가 처리하지 못해 에러발생
billboard = pd.read_csv('billboard.csv',engine='python')

# %%
billboard
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
billboard.describe()
# Out:
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000   63.000000   53.000000   44.750000   38.750000
# 50%    2000.0   81.000000   73.000000   66.000000   61.000000   57.000000
# 75%    2000.0   91.000000   84.000000   79.000000   76.000000   73.250000
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week     ...      x67th.week  \
# count  280.000000  269.000000  260.000000  253.000000     ...             0.0
# mean    52.360714   49.219331   47.119231   46.343874     ...             NaN
# ...

# %%
billboard.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
billboard.tail()
# Out:
#      year   artist.inverted             track  time genre date.entered  \
# 312  2000  Ghostface Killah  Cherchez LaGhost  3:04   R&B   2000-08-05
# 313  2000       Smith, Will       Freakin' It  3:58   Rap   2000-02-12
# 314  2000     Zombie Nation     Kernkraft 400  3:30  Rock   2000-09-02
# 315  2000    Eastsidaz, The          Got Beef  3:58   Rap   2000-07-01
# 316  2000            Fragma    Toca's Miracle  3:22   R&B   2000-10-28
#
#     date.peaked  x1st.week  x2nd.week  x3rd.week     ...      x67th.week  \
# 312  2000-08-05         98        NaN        NaN     ...             NaN
# 313  2000-02-12         99       99.0       99.0     ...             NaN
# 314  2000-09-02         99       99.0        NaN     ...             NaN
# 315  2000-07-01         99       99.0        NaN     ...             NaN
# 316  2000-10-28         99        NaN        NaN     ...             NaN
#
#      x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  \
# ...

# %%
billboard.sample()
# Out:
#      year artist.inverted                        track  time genre  \
# 137  2000   Carter, Aaron  Aaron's Party (Come Get It)  3:23   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 137   2000-08-26  2000-09-16         99       75.0       57.0     ...
#
#      x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# 137         NaN         NaN         NaN         NaN         NaN         NaN
#
#      x73rd.week  x74th.week  x75th.week  x76th.week
# 137         NaN         NaN         NaN         NaN
#
# [1 rows x 83 columns]

# %%
# wide format -> long format

# %%
billboard.columns
# Out:
# Index(['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
#        'date.peaked', 'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week',
#        'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week',
#        'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week',
#        'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week',
#        'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week',
#        'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week',
#        'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week',
#        'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week',
#        'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
# ...

# %%
x = billboard.melt(id_vars=['year', 'artist.inverted', 'track', 'time', 'genre', 'date.entered',
       'date.peaked'],var_name='moon',value_name='points')

# %%
x
# Out:
#        year      artist.inverted  \
# 0      2000      Destiny's Child
# 1      2000              Santana
# 2      2000        Savage Garden
# 3      2000              Madonna
# 4      2000  Aguilera, Christina
# 5      2000                Janet
# 6      2000      Destiny's Child
# 7      2000    Iglesias, Enrique
# 8      2000                Sisqo
# 9      2000             Lonestar
# 10     2000               N'Sync
# 11     2000  Aguilera, Christina
# 12     2000     Vertical Horizon
# 13     2000                Creed
# 14     2000              Aaliyah
# 15     2000      matchbox twenty
# 16     2000        Carey, Mariah
# 17     2000          Hill, Faith
# 18     2000                  Mya
# 19     2000                Dream
# 20     2000        Braxton, Toni
# 21     2000        Anthony, Marc
# 22     2000                  98�
# 23     2000      Destiny's Child
# 24     2000         3 Doors Down
# 25     2000                Sisqo
# 26     2000  Aguilera, Christina
# ...

# %%
x.describe()
# Out:
#           year       points
# count  24092.0  5307.000000
# mean    2000.0    51.052384
# std        0.0    28.966198
# min     2000.0     1.000000
# 25%     2000.0    26.000000
# 50%     2000.0    51.000000
# 75%     2000.0    76.000000
# max     2000.0   100.000000

# %%
x.drop(columns='year') # inplace=True 하면 자신이 바뀌어버리므로 신중해야 한다.
# Out:
#            artist.inverted                                              track  \
# 0          Destiny's Child                           Independent Women Part I
# 1                  Santana                                       Maria, Maria
# 2            Savage Garden                                 I Knew I Loved You
# 3                  Madonna                                              Music
# 4      Aguilera, Christina              Come On Over Baby (All I Want Is You)
# 5                    Janet                              Doesn't Really Matter
# 6          Destiny's Child                                        Say My Name
# 7        Iglesias, Enrique                                        Be With You
# 8                    Sisqo                                         Incomplete
# 9                 Lonestar                                             Amazed
# 10                  N'Sync                                   It's Gonna Be Me
# ...

# %%
x
# Out:
#        year      artist.inverted  \
# 0      2000      Destiny's Child
# 1      2000              Santana
# 2      2000        Savage Garden
# 3      2000              Madonna
# 4      2000  Aguilera, Christina
# 5      2000                Janet
# 6      2000      Destiny's Child
# 7      2000    Iglesias, Enrique
# 8      2000                Sisqo
# 9      2000             Lonestar
# 10     2000               N'Sync
# 11     2000  Aguilera, Christina
# 12     2000     Vertical Horizon
# 13     2000                Creed
# 14     2000              Aaliyah
# 15     2000      matchbox twenty
# 16     2000        Carey, Mariah
# 17     2000          Hill, Faith
# 18     2000                  Mya
# 19     2000                Dream
# 20     2000        Braxton, Toni
# 21     2000        Anthony, Marc
# 22     2000                  98�
# 23     2000      Destiny's Child
# 24     2000         3 Doors Down
# 25     2000                Sisqo
# 26     2000  Aguilera, Christina
# ...

# %%
# axis = 0 행 / axis = 1: 열 index=str, columns={"A": "a", "B": "c"}
# x.rename(index=str, columns={"points":"points4"}) 
x.rename({'artist.inverted':'artist','points':'points'},axis=1)
# Out:
#        year               artist  \
# 0      2000      Destiny's Child
# 1      2000              Santana
# 2      2000        Savage Garden
# 3      2000              Madonna
# 4      2000  Aguilera, Christina
# 5      2000                Janet
# 6      2000      Destiny's Child
# 7      2000    Iglesias, Enrique
# 8      2000                Sisqo
# 9      2000             Lonestar
# 10     2000               N'Sync
# 11     2000  Aguilera, Christina
# 12     2000     Vertical Horizon
# 13     2000                Creed
# 14     2000              Aaliyah
# 15     2000      matchbox twenty
# 16     2000        Carey, Mariah
# 17     2000          Hill, Faith
# 18     2000                  Mya
# 19     2000                Dream
# 20     2000        Braxton, Toni
# 21     2000        Anthony, Marc
# 22     2000                  98�
# 23     2000      Destiny's Child
# 24     2000         3 Doors Down
# 25     2000                Sisqo
# 26     2000  Aguilera, Christina
# ...

# %%
import re

# %%
p = re.compile('[0-9]')

# %%
a = 'wk1t'

# %%
m = p.match(a)

# %%
m

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
a.replace('wk','').replace('t','')
# Out:
# '1'

# %%
x.moon
# Out:
# 0         x1st.week
# 1         x1st.week
# 2         x1st.week
# 3         x1st.week
# 4         x1st.week
# 5         x1st.week
# 6         x1st.week
# 7         x1st.week
# 8         x1st.week
# 9         x1st.week
# 10        x1st.week
# 11        x1st.week
# 12        x1st.week
# 13        x1st.week
# 14        x1st.week
# 15        x1st.week
# 16        x1st.week
# 17        x1st.week
# 18        x1st.week
# 19        x1st.week
# 20        x1st.week
# 21        x1st.week
# 22        x1st.week
# 23        x1st.week
# 24        x1st.week
# 25        x1st.week
# 26        x1st.week
# 27        x1st.week
# 28        x1st.week
# 29        x1st.week
#             ...
# 24062    x76th.week
# 24063    x76th.week
# 24064    x76th.week
# 24065    x76th.week
# 24066    x76th.week
# 24067    x76th.week
# 24068    x76th.week
# 24069    x76th.week
# 24070    x76th.week
# 24071    x76th.week
# 24072    x76th.week
# 24073    x76th.week
# 24074    x76th.week
# 24075    x76th.week
# ...

# %%
[x.replace('x','') for x in x.moon]
# Out:
# ['1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
#  '1st.week',
# ...

# %%
map(lambda x:replace('x',''),x.moon)

# %%
x.moon
# Out:
# 0         1st.week
# 1         1st.week
# 2         1st.week
# 3         1st.week
# 4         1st.week
# 5         1st.week
# 6         1st.week
# 7         1st.week
# 8         1st.week
# 9         1st.week
# 10        1st.week
# 11        1st.week
# 12        1st.week
# 13        1st.week
# 14        1st.week
# 15        1st.week
# 16        1st.week
# 17        1st.week
# 18        1st.week
# 19        1st.week
# 20        1st.week
# 21        1st.week
# 22        1st.week
# 23        1st.week
# 24        1st.week
# 25        1st.week
# 26        1st.week
# 27        1st.week
# 28        1st.week
# 29        1st.week
#            ...
# 24062    76th.week
# 24063    76th.week
# 24064    76th.week
# 24065    76th.week
# 24066    76th.week
# 24067    76th.week
# 24068    76th.week
# 24069    76th.week
# 24070    76th.week
# 24071    76th.week
# 24072    76th.week
# 24073    76th.week
# 24074    76th.week
# 24075    76th.week
# 24076    76th.week
# 24077    76th.week
# ...

# %%
x.moon.str

# %%
dir(x.moon.str)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_freeze',
#  '_get_series_list',
#  '_is_categorical',
#  '_make_accessor',
#  '_orig',
#  '_validate',
#  '_wrap_result',
#  'capitalize',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'get',
#  'get_dummies',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
# ...

# %%
x.moon = x.moon.str.replace('x','')

# %%
x
# Out:
#        year      artist.inverted  \
# 0      2000      Destiny's Child
# 1      2000              Santana
# 2      2000        Savage Garden
# 3      2000              Madonna
# 4      2000  Aguilera, Christina
# 5      2000                Janet
# 6      2000      Destiny's Child
# 7      2000    Iglesias, Enrique
# 8      2000                Sisqo
# 9      2000             Lonestar
# 10     2000               N'Sync
# 11     2000  Aguilera, Christina
# 12     2000     Vertical Horizon
# 13     2000                Creed
# 14     2000              Aaliyah
# 15     2000      matchbox twenty
# 16     2000        Carey, Mariah
# 17     2000          Hill, Faith
# 18     2000                  Mya
# 19     2000                Dream
# 20     2000        Braxton, Toni
# 21     2000        Anthony, Marc
# 22     2000                  98�
# 23     2000      Destiny's Child
# 24     2000         3 Doors Down
# 25     2000                Sisqo
# 26     2000  Aguilera, Christina
# ...
