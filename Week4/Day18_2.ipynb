# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# 열만 가지고 오는 방식 2가지 -> dictionary 방식 / property 방식  <= numpy의 structured array 에서 계승

# %%
# property 방식 단점 2가지 -> 특수문자, 공백이 있으면 쓸 수 없다. / column명이 python의 키워드와 같을 때 쓸 수 없다.

# %%
# 행을 뽑는 방식 2가지 => loc , iloc

# %%
# 셀을 뽑는 방식 4가지 => loc, iloc, at, iat

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data.size # numpy 의 size가 불리게 되므로 dictionary 방식을 써야 한다. # size를 카테고리로 변환
# Out:
# 1708

# %%
data['size'] = data['size'].astype('category') # mutable 이므로 할당이 가능하며 broadcasting 기법으로 동시에 데이터 삽입

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null category
# dtypes: category(1), float64(2), object(4)
# memory usage: 12.0+ KB

# %%
data.describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
data.describe(include=['object','category'])
# Out:
#          sex smoker  day    time  size
# count    244    244  244     244   244
# unique     2      2    4       2     6
# top     Male     No  Sat  Dinner     2
# freq     157    151   87     176   156

# %%
data['tip'].mean()
# Out:
# 2.9982786885245902

# %%
data['tip'].max()
# Out:
# 10.0

# %%
data['tip'].min()
# Out:
# 1.0

# %%
data.mean() # axis=0이 들어가서 아래와 같이 평균값 산출
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
# 파일 불러들린다. # 5총사 # 변환 # 기초통계 # 집합통계

# %%
# 집합통계 3가지 방식 -> group by

# %%
dt = data.groupby('sex')

# %%
dir(dt)
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_agg_doc',
#  '_aggregate',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_assure_grouper',
#  '_block_agg_axis',
#  '_bool_agg',
#  '_builtin_table',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
#  '_cython_table',
# ...

# %%
# 숫자를 통한 indexing에는   __getitem__ / __iter__ 는 for 에 쓸 수 있다.

# %%
for i,j in data.groupby('sex'): # split <- 성별로 나누어줌 
    print(i,'/',j)
# Out:
# Female /      total_bill   tip     sex smoker   day    time size
# 0         16.99  1.01  Female     No   Sun  Dinner    2
# 4         24.59  3.61  Female     No   Sun  Dinner    4
# 11        35.26  5.00  Female     No   Sun  Dinner    4
# 14        14.83  3.02  Female     No   Sun  Dinner    2
# 16        10.33  1.67  Female     No   Sun  Dinner    3
# 18        16.97  3.50  Female     No   Sun  Dinner    3
# 21        20.29  2.75  Female     No   Sat  Dinner    2
# 22        15.77  2.23  Female     No   Sat  Dinner    2
# 29        19.65  3.00  Female     No   Sat  Dinner    2
# 32        15.06  3.00  Female     No   Sat  Dinner    2
# 33        20.69  2.45  Female     No   Sat  Dinner    4
# 37        16.93  3.07  Female     No   Sat  Dinner    3
# 51        10.29  2.60  Female     No   Sun  Dinner    2
# 52        34.81  5.20  Female     No   Sun  Dinner    4
# 57        26.41  1.50  Female     No   Sat  Dinner    2
# 66        16.45  2.47  Female     No   Sat  Dinner    2
# ...

# %%
data.groupby('sex').mean() # 집합통계
# Out:
#         total_bill       tip
# sex
# Female   18.056897  2.833448
# Male     20.744076  3.089618

# %%
# tidy data 는 split이 된다.

# %%
data.groupby(['sex','smoker']).max() # 집합통계
# Out:
#                 day   time   tip  total_bill
# sex    smoker
# Female No      Thur  Lunch   5.2       35.83
#        Yes     Thur  Lunch   6.5       44.30
# Male   No      Thur  Lunch   9.0       48.33
#        Yes     Thur  Lunch  10.0       50.81

# %%
data.groupby(['sex','smoker']).max()['tip'] # 계산복잡도가 높다 => 비추
# Out:
# sex     smoker
# Female  No         5.2
#         Yes        6.5
# Male    No         9.0
#         Yes       10.0
# Name: tip, dtype: float64

# %%
data.groupby(['sex','smoker'])['tip'].max() # 계산복잡도가 덜하다 => 강추
# Out:
# sex     smoker
# Female  No         5.2
#         Yes        6.5
# Male    No         9.0
#         Yes       10.0
# Name: tip, dtype: float64

# %%
data.groupby(['sex','smoker'])[['tip']].max() # fancy indexing
# Out:
#                 tip
# sex    smoker
# Female No       5.2
#        Yes      6.5
# Male   No       9.0
#        Yes     10.0

# %%
data.groupby(['sex','smoker'])[['tip']].agg([np.max,np.mean]) # numpy 방식의 인자를 쓴다.
# Out:
#                 tip
#                amax      mean
# sex    smoker
# Female No       5.2  2.773519
#        Yes      6.5  2.931515
# Male   No       9.0  3.113402
#        Yes     10.0  3.051167
