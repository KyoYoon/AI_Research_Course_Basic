# %%
import numpy as np

# %%
import pandas as pd

# %%
country_timeseries = pd.read_csv('country_timeseries.csv')

# %%
country_timeseries.columns
# Out:
# Index(['Date', 'Day', 'Cases_Guinea', 'Cases_Liberia', 'Cases_SierraLeone',
#        'Cases_Nigeria', 'Cases_Senegal', 'Cases_UnitedStates', 'Cases_Spain',
#        'Cases_Mali', 'Deaths_Guinea', 'Deaths_Liberia', 'Deaths_SierraLeone',
#        'Deaths_Nigeria', 'Deaths_Senegal', 'Deaths_UnitedStates',
#        'Deaths_Spain', 'Deaths_Mali'],
#       dtype='object')

# %%
x = country_timeseries.melt(id_vars=['Date', 'Day'])

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 4 columns):
# Date        1952 non-null object
# Day         1952 non-null int64
# variable    1952 non-null object
# value       738 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.1+ KB

# %%
dt = pd.to_datetime(x.Date)

# %%
x.index = dt # 시간, 날짜를 인덱스로 만든다.

# %%
x['2015-01-03':'2015-01-05']
# Out:
#                 Date  Day             variable    value
# Date
# 2015-01-05  1/5/2015  289         Cases_Guinea   2776.0
# 2015-01-04  1/4/2015  288         Cases_Guinea   2775.0
# 2015-01-03  1/3/2015  287         Cases_Guinea   2769.0
# 2015-01-05  1/5/2015  289        Cases_Liberia      NaN
# 2015-01-04  1/4/2015  288        Cases_Liberia      NaN
# 2015-01-03  1/3/2015  287        Cases_Liberia   8166.0
# 2015-01-05  1/5/2015  289    Cases_SierraLeone  10030.0
# 2015-01-04  1/4/2015  288    Cases_SierraLeone   9780.0
# 2015-01-03  1/3/2015  287    Cases_SierraLeone   9722.0
# 2015-01-05  1/5/2015  289        Cases_Nigeria      NaN
# 2015-01-04  1/4/2015  288        Cases_Nigeria      NaN
# 2015-01-03  1/3/2015  287        Cases_Nigeria      NaN
# 2015-01-05  1/5/2015  289        Cases_Senegal      NaN
# 2015-01-04  1/4/2015  288        Cases_Senegal      NaN
# 2015-01-03  1/3/2015  287        Cases_Senegal      NaN
# 2015-01-05  1/5/2015  289   Cases_UnitedStates      NaN
# ...

# %%
x.set_index('Date')
# Out:
#             Day      variable   value
# Date
# 1/5/2015    289  Cases_Guinea  2776.0
# 1/4/2015    288  Cases_Guinea  2775.0
# 1/3/2015    287  Cases_Guinea  2769.0
# 1/2/2015    286  Cases_Guinea     NaN
# 12/31/2014  284  Cases_Guinea  2730.0
# 12/28/2014  281  Cases_Guinea  2706.0
# 12/27/2014  280  Cases_Guinea  2695.0
# 12/24/2014  277  Cases_Guinea  2630.0
# 12/21/2014  273  Cases_Guinea  2597.0
# 12/20/2014  272  Cases_Guinea  2571.0
# 12/18/2014  271  Cases_Guinea     NaN
# 12/14/2014  267  Cases_Guinea  2416.0
# 12/9/2014   262  Cases_Guinea     NaN
# 12/7/2014   260  Cases_Guinea  2292.0
# 12/3/2014   256  Cases_Guinea     NaN
# 11/30/2014  253  Cases_Guinea  2164.0
# 11/28/2014  251  Cases_Guinea     NaN
# 11/23/2014  246  Cases_Guinea  2134.0
# 11/22/2014  245  Cases_Guinea     NaN
# 11/18/2014  241  Cases_Guinea  2047.0
# 11/16/2014  239  Cases_Guinea  1971.0
# 11/15/2014  238  Cases_Guinea     NaN
# 11/11/2014  234  Cases_Guinea  1919.0
# ...

# %%
x['2015-01-03':'2015-01-13']
# Out:
#                 Date  Day             variable    value
# Date
# 2015-01-05  1/5/2015  289         Cases_Guinea   2776.0
# 2015-01-04  1/4/2015  288         Cases_Guinea   2775.0
# 2015-01-03  1/3/2015  287         Cases_Guinea   2769.0
# 2015-01-05  1/5/2015  289        Cases_Liberia      NaN
# 2015-01-04  1/4/2015  288        Cases_Liberia      NaN
# 2015-01-03  1/3/2015  287        Cases_Liberia   8166.0
# 2015-01-05  1/5/2015  289    Cases_SierraLeone  10030.0
# 2015-01-04  1/4/2015  288    Cases_SierraLeone   9780.0
# 2015-01-03  1/3/2015  287    Cases_SierraLeone   9722.0
# 2015-01-05  1/5/2015  289        Cases_Nigeria      NaN
# 2015-01-04  1/4/2015  288        Cases_Nigeria      NaN
# 2015-01-03  1/3/2015  287        Cases_Nigeria      NaN
# 2015-01-05  1/5/2015  289        Cases_Senegal      NaN
# 2015-01-04  1/4/2015  288        Cases_Senegal      NaN
# 2015-01-03  1/3/2015  287        Cases_Senegal      NaN
# 2015-01-05  1/5/2015  289   Cases_UnitedStates      NaN
# ...
