# %%
# Pandas 
# 1. EDA Exploratory Data Analysis -> Big data  
# 2. 전처리 (Preprocessing) -> AI

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
type(data.values)
# Out:
# numpy.ndarray

# %%
# numpy + index => pandas / numpy + GPU => tensorflow

# %%
data['tip'] # structured array / dictionary 방식
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
# 5      4.71
# 6      2.00
# 7      3.12
# 8      1.96
# 9      3.23
# 10     1.71
# 11     5.00
# 12     1.57
# 13     3.00
# 14     3.02
# 15     3.92
# 16     1.67
# 17     3.71
# 18     3.50
# 19     3.35
# 20     4.08
# 21     2.75
# 22     2.23
# 23     7.58
# 24     3.18
# 25     2.34
# 26     2.00
# 27     2.00
# 28     4.30
# 29     3.00
#        ...
# 214    6.50
# 215    1.10
# 216    3.00
# 217    1.50
# 218    1.44
# 219    3.09
# 220    2.20
# 221    3.48
# 222    1.92
# 223    3.00
# 224    1.58
# 225    2.50
# 226    2.00
# 227    3.00
# 228    2.72
# 229    2.88
# 230    2.00
# 231    3.00
# 232    3.39
# 233    1.47
# 234    3.00
# 235    1.25
# 236    1.00
# 237    1.17
# 238    4.67
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
# numpy + index -> series

# %%
type(data['tip'])
# Out:
# pandas.core.series.Series

# %%
data[['tip','sex']] # list로 가져온다. tuple은 지원안함
# Out:
#       tip     sex
# 0    1.01  Female
# 1    1.66    Male
# 2    3.50    Male
# 3    3.31    Male
# 4    3.61  Female
# 5    4.71    Male
# 6    2.00    Male
# 7    3.12    Male
# 8    1.96    Male
# 9    3.23    Male
# 10   1.71    Male
# 11   5.00  Female
# 12   1.57    Male
# 13   3.00    Male
# 14   3.02  Female
# 15   3.92    Male
# 16   1.67  Female
# 17   3.71    Male
# 18   3.50  Female
# 19   3.35    Male
# 20   4.08    Male
# 21   2.75  Female
# 22   2.23  Female
# 23   7.58    Male
# 24   3.18    Male
# 25   2.34    Male
# 26   2.00    Male
# 27   2.00    Male
# 28   4.30    Male
# 29   3.00  Female
# ..    ...     ...
# 214  6.50  Female
# 215  1.10  Female
# 216  3.00    Male
# 217  1.50    Male
# 218  1.44    Male
# 219  3.09  Female
# 220  2.20    Male
# 221  3.48  Female
# 222  1.92    Male
# 223  3.00  Female
# 224  1.58    Male
# 225  2.50  Female
# 226  2.00  Female
# 227  3.00    Male
# 228  2.72    Male
# 229  2.88  Female
# 230  2.00    Male
# 231  3.00    Male
# ...

# %%
data.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
# 5      4.71
# 6      2.00
# 7      3.12
# 8      1.96
# 9      3.23
# 10     1.71
# 11     5.00
# 12     1.57
# 13     3.00
# 14     3.02
# 15     3.92
# 16     1.67
# 17     3.71
# 18     3.50
# 19     3.35
# 20     4.08
# 21     2.75
# 22     2.23
# 23     7.58
# 24     3.18
# 25     2.34
# 26     2.00
# 27     2.00
# 28     4.30
# 29     3.00
#        ...
# 214    6.50
# 215    1.10
# 216    3.00
# 217    1.50
# 218    1.44
# 219    3.09
# 220    2.20
# 221    3.48
# 222    1.92
# 223    3.00
# 224    1.58
# 225    2.50
# 226    2.00
# 227    3.00
# 228    2.72
# 229    2.88
# 230    2.00
# 231    3.00
# 232    3.39
# 233    1.47
# 234    3.00
# 235    1.25
# 236    1.00
# 237    1.17
# 238    4.67
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
data.sex # propery descriptor 사용
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9        Male
# 10       Male
# 11     Female
# 12       Male
# 13       Male
# 14     Female
# 15       Male
# 16     Female
# 17       Male
# 18     Female
# 19       Male
# 20       Male
# 21     Female
# 22     Female
# 23       Male
# 24       Male
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29     Female
#         ...
# 214    Female
# 215    Female
# 216      Male
# 217      Male
# 218      Male
# 219    Female
# 220      Male
# 221    Female
# 222      Male
# 223    Female
# 224      Male
# 225    Female
# 226    Female
# 227      Male
# 228      Male
# 229    Female
# 230      Male
# 231      Male
# 232      Male
# 233      Male
# 234      Male
# 235      Male
# 236      Male
# 237      Male
# 238    Female
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# ...

# %%
# Pandas의 데이터 추출 방식 
# 1. numpy 의 structured array (dictionary 방식)
# 2. property descriptor 사용

# %%
data.iloc[2]
# Out:
# total_bill     21.01
# tip              3.5
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               3
# Name: 2, dtype: object

# %%
# data2 = pd.DataFrame.from_csv => deprecated

# %%
# https://archive.ics.uci.edu/ml/datasets/iris => data folder 클릭 => url 추출

# %%
# header 가 없어서 옵션을 아래와 같이 header=None 으로 설정해서 가지고 온다.

# %%
data2 = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)

# %%
data2
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# 4    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
# string type을 object 라고 한다.

# %%
data2.describe(include='object')
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data2.describe(include='object')
# Out:
#                       4
# count               150
# unique                3
# top     Iris-versicolor
# freq                 50

# %%
data2.describe(include='all')
# Out:
#                  0           1           2           3                4
# count   150.000000  150.000000  150.000000  150.000000              150
# unique         NaN         NaN         NaN         NaN                3
# top            NaN         NaN         NaN         NaN  Iris-versicolor
# freq           NaN         NaN         NaN         NaN               50
# mean      5.843333    3.054000    3.758667    1.198667              NaN
# std       0.828066    0.433594    1.764420    0.763161              NaN
# min       4.300000    2.000000    1.000000    0.100000              NaN
# 25%       5.100000    2.800000    1.600000    0.300000              NaN
# 50%       5.800000    3.000000    4.350000    1.300000              NaN
# 75%       6.400000    3.300000    5.100000    1.800000              NaN
# max       7.900000    4.400000    6.900000    2.500000              NaN

# %%
data2.head(n=5)
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data2.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
data2.tail()
# Out:
#        0    1    2    3               4
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
data2.sample()
# Out:
#       0    1    2    3                4
# 94  5.6  2.7  4.2  1.3  Iris-versicolor

# %%
import seaborn as sns

# %%
sns.pairplot(data2)

# %%
# index / column index / data frame / data frame 한 줄 series (행과 열 둘 다 해당)

# %%
dir(data2)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
data3 = data2[[0,1,2,3]]

# %%
data3
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 27   5.2  3.5  1.5  0.2
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
data3[0] = 0
# Out:
# /Users/jung-kyoyoon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data2 # 기본이 copy
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
data3 = data2[[0,1,2,3]].copy() # fancy indexing => copy

# %%
data3
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 27   5.2  3.5  1.5  0.2
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
data2[[0]] # '[[]]'의 경우 fancy indexing => dataframe 으로 가져온다.
# Out:
#        0
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# 8    4.4
# 9    4.9
# 10   5.4
# 11   4.8
# 12   4.8
# 13   4.3
# 14   5.8
# 15   5.7
# 16   5.4
# 17   5.1
# 18   5.7
# 19   5.1
# 20   5.4
# 21   5.1
# 22   4.6
# 23   5.1
# 24   4.8
# 25   5.0
# 26   5.0
# 27   5.2
# 28   5.2
# 29   4.7
# ..   ...
# 120  6.9
# 121  5.6
# 122  7.7
# 123  6.3
# 124  6.7
# 125  7.2
# 126  6.2
# 127  6.1
# 128  6.4
# 129  7.2
# 130  7.4
# 131  7.9
# 132  6.4
# 133  6.3
# 134  6.1
# 135  7.7
# 136  6.3
# 137  6.4
# 138  6.0
# 139  6.9
# 140  6.7
# 141  6.9
# 142  5.8
# 143  6.8
# 144  6.7
# 145  6.7
# 146  6.3
# 147  6.5
# 148  6.2
# 149  5.9
#
# [150 rows x 1 columns]

# %%
data2[0] # '[]'의 경우 series 로 가져온다.
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: 0, Length: 150, dtype: float64

# %%
data3.to_csv('moon.csv')

# %%
data2.loc[0]
# Out:
# 0            5.1
# 1            3.5
# 2            1.4
# 3            0.2
# 4    Iris-setosa
# Name: 0, dtype: object

# %%
data2.loc[148] # 행을 가져온다.
# Out:
# 0               6.2
# 1               3.4
# 2               5.4
# 3               2.3
# 4    Iris-virginica
# Name: 148, dtype: object

# %%
data2.loc[0,1]
# Out:
# 3.5

# %%
data2.loc[0:40]
# Out:
#       0    1    2    3            4
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# ...

# %%
data2.iloc[0:40]
# Out:
#       0    1    2    3            4
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# ...

# %%
data2.iloc[0:2,[0,1]]
# Out:
#      0    1
# 0  5.1  3.5
# 1  4.9  3.0

# %%
data2.at[0,2]
# Out:
# 1.4

# %%
data2.iat[0,2]
# Out:
# 1.4

# %%
# %timeit data2.iat[0,2]
# Out:
# 4.96 µs ± 86.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit data2.at[0,2]
# Out:
# 4.34 µs ± 266 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit data2.iloc[0,2]
# Out:
# 8 µs ± 243 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit data2.loc[0,2]
# Out:
# 6.7 µs ± 84.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
data2[0].mean()
# Out:
# 5.843333333333335

# %%
data2.mean(axis=0) # 0 은 행끼리 더한 값
# Out:
# 0    5.843333
# 1    3.054000
# 2    3.758667
# 3    1.198667
# dtype: float64

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
data[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# 5         25.29  4.71
# 6          8.77  2.00
# 7         26.88  3.12
# 8         15.04  1.96
# 9         14.78  3.23
# 10        10.27  1.71
# 11        35.26  5.00
# 12        15.42  1.57
# 13        18.43  3.00
# 14        14.83  3.02
# 15        21.58  3.92
# 16        10.33  1.67
# 17        16.29  3.71
# 18        16.97  3.50
# 19        20.65  3.35
# 20        17.92  4.08
# 21        20.29  2.75
# 22        15.77  2.23
# 23        39.42  7.58
# 24        19.82  3.18
# 25        17.81  2.34
# 26        13.37  2.00
# 27        12.69  2.00
# 28        21.70  4.30
# 29        19.65  3.00
# ..          ...   ...
# 214       28.17  6.50
# 215       12.90  1.10
# 216       28.15  3.00
# 217       11.59  1.50
# 218        7.74  1.44
# 219       30.14  3.09
# 220       12.16  2.20
# 221       13.42  3.48
# 222        8.58  1.92
# ...

# %%
data[['total_bill','tip']].mean(axis=0)
# Out:
# total_bill    19.785943
# tip            2.998279
# dtype: float64

# %%
data[['total_bill','tip']].max(axis=0)
# Out:
# total_bill    50.81
# tip           10.00
# dtype: float64

# %%
data[['total_bill','tip']].min(axis=0)
# Out:
# total_bill    3.07
# tip           1.00
# dtype: float64

# %%
data['tip'] is data.tip
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
# 5      4.71
# 6      2.00
# 7      3.12
# 8      1.96
# 9      3.23
# 10     1.71
# 11     5.00
# 12     1.57
# 13     3.00
# 14     3.02
# 15     3.92
# 16     1.67
# 17     3.71
# 18     3.50
# 19     3.35
# 20     4.08
# 21     2.75
# 22     2.23
# 23     7.58
# 24     3.18
# 25     2.34
# 26     2.00
# 27     2.00
# 28     4.30
# 29     3.00
#        ...
# 214    6.50
# 215    1.10
# 216    3.00
# 217    1.50
# 218    1.44
# 219    3.09
# 220    2.20
# 221    3.48
# 222    1.92
# 223    3.00
# 224    1.58
# 225    2.50
# 226    2.00
# 227    3.00
# 228    2.72
# 229    2.88
# 230    2.00
# 231    3.00
# 232    3.39
# 233    1.47
# 234    3.00
# 235    1.25
# 236    1.00
# 237    1.17
# 238    4.67
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
data['tip'] is data.tip
# Out:
# True

# %%
data['tip2'] = 0

# %%
data # broadcasting 됨
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip2
# 0         16.99  1.01  Female     No   Sun  Dinner     2     0
# 1         10.34  1.66    Male     No   Sun  Dinner     3     0
# 2         21.01  3.50    Male     No   Sun  Dinner     3     0
# 3         23.68  3.31    Male     No   Sun  Dinner     2     0
# 4         24.59  3.61  Female     No   Sun  Dinner     4     0
# 5         25.29  4.71    Male     No   Sun  Dinner     4     0
# 6          8.77  2.00    Male     No   Sun  Dinner     2     0
# 7         26.88  3.12    Male     No   Sun  Dinner     4     0
# 8         15.04  1.96    Male     No   Sun  Dinner     2     0
# 9         14.78  3.23    Male     No   Sun  Dinner     2     0
# 10        10.27  1.71    Male     No   Sun  Dinner     2     0
# 11        35.26  5.00  Female     No   Sun  Dinner     4     0
# 12        15.42  1.57    Male     No   Sun  Dinner     2     0
# 13        18.43  3.00    Male     No   Sun  Dinner     4     0
# ...

# %%
data['tip2'] = data.tip / data.total_bill # vectorization 기법 => element 끼리 계산

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size      tip2
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# 5         25.29  4.71    Male     No   Sun  Dinner     4  0.186240
# 6          8.77  2.00    Male     No   Sun  Dinner     2  0.228050
# 7         26.88  3.12    Male     No   Sun  Dinner     4  0.116071
# 8         15.04  1.96    Male     No   Sun  Dinner     2  0.130319
# 9         14.78  3.23    Male     No   Sun  Dinner     2  0.218539
# 10        10.27  1.71    Male     No   Sun  Dinner     2  0.166504
# 11        35.26  5.00  Female     No   Sun  Dinner     4  0.141804
# 12        15.42  1.57    Male     No   Sun  Dinner     2  0.101816
# ...

# %%
data['tip2'].max(axis=0)
# Out:
# 0.710344827586207

# %%
data['tip2'].min(axis=0)
# Out:
# 0.03563813585135547

# %%
# map, filter, reduce -> higher order function 3가지

# %%
# reduction 기법이 들어간 함수에는 axis 개념을 적용할 수 있다.

# %%
data[data.tip2>0.5]
# Out:
#      total_bill   tip   sex smoker  day    time  size      tip2
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2  0.710345

# %%
data[data.tip2>0.3]
# Out:
#      total_bill   tip     sex smoker  day    time  size      tip2
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667

# %%
data[data.tip2>0.3].shape / data.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-5cb2c9c44d5b> in <module>
# ----> 1 data[data.tip2>0.3].shape / data.shape
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'tuple'

# %%
data[data.tip2>0.3] / len(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
len(data)
# Out:
# 244

# %%
# shape, data type

# %%
data.shape
# Out:
# (244, 8)

# %%
# skewness 외도 (왜곡) & kurtosis 첨도 (얼마나 위 또는 아래로 뻗었나..) -> 정규분포의 모양 파악

# %%
data.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
data.smoker.value_counts()[0] # sequence type
# Out:
# 151

# %%
data.smoker.value_counts()['No'] # dictionary type
# Out:
# 151
