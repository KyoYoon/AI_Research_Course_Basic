# %%
import pandas as pd

# %%
pew = pd.read_csv('pew.txt',sep='\t') # '\t'로 구분

# %%
pew # 분석하기 힘든 데이터프레임 -> column 명 변환 -> melt 쓰기
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
# info, describe, head, tail, sample => 5총사

# %%
# info

# %%
pew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
# religion              18 non-null object
# <$10k                 18 non-null int64
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 1.6+ KB

# %%
# describe

# %%
pew.describe()
# Out:
#             <$10k     $10-20k      $20-30k     $30-40k     $40-50k  \
# count   18.000000   18.000000    18.000000   18.000000   18.000000
# mean   107.222222  154.500000   186.500000  183.444444  171.388889
# std    168.931784  255.172433   309.891869  291.470354  271.144446
# min      1.000000    2.000000     3.000000    4.000000    2.000000
# 25%     12.250000   14.750000    17.000000   15.750000   15.000000
# 50%     20.000000   27.000000    33.500000   40.000000   34.000000
# 75%    170.000000  193.000000   192.000000  198.750000  166.750000
# max    575.000000  869.000000  1064.000000  982.000000  881.000000
#
#            $50-75k    $75-100k   $100-150k       >150k  Don't know/refused
# count    18.000000   18.000000   18.000000   18.000000           18.000000
# mean    288.055556  221.666667  177.611111  144.888889          340.055556
# std     458.442436  345.078849  275.679724  205.224952          530.523878
# ...

# %%
# sample

# %%
pew.sample
# Out:
# <bound method NDFrame.sample of                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
# head

# %%
pew.head()
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
# tail

# %%
pew.tail()
# Out:
#                  religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 13               Orthodox     13       17       23       32       32       47
# 14        Other Christian      9        7       11       13       13       14
# 15           Other Faiths     20       33       40       46       49       63
# 16  Other World Religions      5        2        3        4        2        7
# 17           Unaffiliated    217      299      374      365      341      528
#
#     $75-100k  $100-150k  >150k  Don't know/refused
# 13        38         42     46                  73
# 14        18         14     12                  18
# 15        46         40     41                  71
# 16         3          4      4                   8
# 17       407        321    258                 597

# %%
pd.melt(pew)
# Out:
#                variable                    value
# 0              religion                 Agnostic
# 1              religion                  Atheist
# 2              religion                 Buddhist
# 3              religion                 Catholic
# 4              religion       Don’t know/refused
# 5              religion         Evangelical Prot
# 6              religion                    Hindu
# 7              religion  Historically Black Prot
# 8              religion        Jehovah's Witness
# 9              religion                   Jewish
# 10             religion            Mainline Prot
# 11             religion                   Mormon
# 12             religion                   Muslim
# 13             religion                 Orthodox
# 14             religion          Other Christian
# 15             religion             Other Faiths
# 16             religion    Other World Religions
# 17             religion             Unaffiliated
# ...

# %%
pd.melt(pew,id_vars=['religion',"Don't know/refused"]) #id_vars 고정시키고 싶은 칼럼
# Out:
#                     religion  Don't know/refused   variable  value
# 0                   Agnostic                  96      <$10k     27
# 1                    Atheist                  76      <$10k     12
# 2                   Buddhist                  54      <$10k     27
# 3                   Catholic                1489      <$10k    418
# 4         Don’t know/refused                 116      <$10k     15
# 5           Evangelical Prot                1529      <$10k    575
# 6                      Hindu                  37      <$10k      1
# 7    Historically Black Prot                 339      <$10k    228
# 8          Jehovah's Witness                  37      <$10k     20
# 9                     Jewish                 162      <$10k     19
# 10             Mainline Prot                1328      <$10k    289
# 11                    Mormon                  69      <$10k     29
# 12                    Muslim                  22      <$10k      6
# ...

# %%
# wide format 을 long format 으로 전환 => melt를 쓰는 이유 / 데이터 분석을 용이하게 하기 위함 
# (column이 많을수록 복잡도가 증가한다, 똑같은 의미를 가진 것들은 row로 바꿔라)

# %%
t = pd.melt(pew,id_vars=['religion',"Don't know/refused"])

# %%
s = t.iloc[:,-2:]

# %%
s
# Out:
#       variable  value
# 0        <$10k     27
# 1        <$10k     12
# 2        <$10k     27
# 3        <$10k    418
# 4        <$10k     15
# 5        <$10k    575
# 6        <$10k      1
# 7        <$10k    228
# 8        <$10k     20
# 9        <$10k     19
# 10       <$10k    289
# 11       <$10k     29
# 12       <$10k      6
# 13       <$10k     13
# 14       <$10k      9
# 15       <$10k     20
# 16       <$10k      5
# 17       <$10k    217
# 18     $10-20k     34
# 19     $10-20k     27
# 20     $10-20k     21
# 21     $10-20k    617
# 22     $10-20k     14
# 23     $10-20k    869
# 24     $10-20k      9
# 25     $10-20k    244
# 26     $10-20k     27
# 27     $10-20k     19
# 28     $10-20k    495
# 29     $10-20k     40
# ..         ...    ...
# 132  $100-150k     48
# 133  $100-150k     81
# 134  $100-150k     11
# 135  $100-150k     87
# 136  $100-150k    753
# 137  $100-150k     49
# 138  $100-150k      8
# 139  $100-150k     42
# 140  $100-150k     14
# ...

# %%
s.plot.bar()

# %%
import seaborn as sns

# %%
sns.barplot()
